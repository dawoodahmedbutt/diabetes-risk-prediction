# %% [markdown]
# **Archived — superseded.** This notebook loaded the dataset via the UCI ML Repository API (`ucimlrepo`). The project switched to using a static local CSV from Kaggle. Retained for reference only.

# %% [markdown]
# **This notebook is now redundant as I have used a static dataset**

# %% [markdown]
# The dataset was accessed using the official Python interface provided by the UCI Machine Learning Repository (ucimlrepo). The data loading code follows the example provided in the dataset documentation.

# %%
import os
os.chdir("/Users/dawoodbutt/Desktop/10. UNI/4. Data Mining/individual assessment/diabetes-risk")

print("Working directory:", os.getcwd())
# Out:
# Working directory: /Users/dawoodbutt/Desktop/10. UNI/4. Data Mining/individual assessment/diabetes-risk

# %%
from ucimlrepo import fetch_ucirepo 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# fetch dataset 
cdc_diabetes_health_indicators = fetch_ucirepo(id=891) 
  
# data (as pandas dataframes) 
X = cdc_diabetes_health_indicators.data.features 
y = cdc_diabetes_health_indicators.data.targets 
  
# metadata 
print(cdc_diabetes_health_indicators.metadata) 
  
# variable information 
print(cdc_diabetes_health_indicators.variables)
# Out:
# {'uci_id': 891, 'name': 'CDC Diabetes Health Indicators', 'repository_url': 'https://archive.ics.uci.edu/dataset/891/cdc+diabetes+health+indicators', 'data_url': 'https://archive.ics.uci.edu/static/public/891/data.csv', 'abstract': 'The Diabetes Health Indicators Dataset contains healthcare statistics and lifestyle survey information about people in general along with their diagnosis of diabetes. The 35 features consist of some demographics, lab test results, and answers to survey questions for each patient. The target variable for classification is whether a patient has diabetes, is pre-diabetic, or healthy. ', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Tabular', 'Multivariate'], 'num_instances': 253680, 'num_features': 21, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Sex', 'Age', 'Education Level', 'Income'], 'target_col': ['Diabetes_binary'], 'index_col': ['ID'], 'has_missing_values': 'no', 'missing_values_symbol': None, 'yea
# ...

# %%
# Combine features and targets into a single dataframe
df = pd.concat([X, y], axis=1)

# Quick checks on the data
print("X shape:", X.shape)
print("y shape:", y.shape)
print("df shape:", df.shape)
print("\nTarget columns:", y.columns.tolist())
print("\nFirst 5 rows:")
display(df.head())
# Out:
# X shape: (253680, 21)
# y shape: (253680, 1)
# df shape: (253680, 22)
#
# Target columns: ['Diabetes_binary']
#
# First 5 rows:
#    HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  HeartDiseaseorAttack  \
# 0       1         1          1   40       1       0                     0
# 1       0         0          0   25       1       0                     0
# 2       1         1          1   28       0       0                     0
# 3       1         0          1   27       0       0                     0
# 4       1         1          1   24       0       0                     0
#
#    PhysActivity  Fruits  Veggies  ...  NoDocbcCost  GenHlth  MentHlth  \
# 0             0       0        1  ...            0        5        18
# 1             1       0        0  ...            1        3         0
# 2             0       1        0  ...            1        5        30
# 3             1       1        1  ...            0        2         0
# ...

# %%
# Save data to csv

os.makedirs("data/raw", exist_ok=True)
df.to_csv("data/raw/cdc_diabetes_health_indicators.csv", index=False)
